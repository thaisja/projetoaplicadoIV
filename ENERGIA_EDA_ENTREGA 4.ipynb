# %% [markdown]
# <a href="https://colab.research.google.com/github/thaisja/projetoaplicadoIV/blob/main/ENERGIA_EDA_ENTREGA%204.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PROJETO APLICADO IV - Ciência de Dados EaD - 2026/01
# Entrega 4

# %% [markdown]
# # **MONITORAMENTO INTELIGENTE DE CONSUMO:**
# REDUZINDO O DESPERDÍCIO NA INDÚSTRIA BRASILEIRA ATRAVÉS DE MODELAGEM PREDITIVA

# %% [markdown]
# **Identificação do Grupo e Opção do Projeto**
#
# Aluno1 = 'FELIPE GRACIANO DE MOURA RAMOS
#
# Aluno2 = 'JOAO PEDRO ROCHA ABBADE
#
# Aluno3 = 'MARCOS DAVI DUARTE ABIBE
#
# Aluno4 = 'THAIS JORGE AZEVEDO

# %% [markdown]
# ## **1. Introdução**
#
# O presente projeto insere-se no contexto da Indústria 4.0 e da eficiência energética, áreas que integram tecnologia, sustentabilidade e análise de dados aplicada. Com o avanço da digitalização industrial, torna-se cada vez mais necessário o uso de ferramentas analíticas capazes de interpretar grandes volumes de dados operacionais e transformá-los em informações estratégicas. Nesse cenário, a análise de séries temporais aliada à inteligência artificial apresenta-se como uma solução promissora para otimização de processos e redução de desperdícios.
#
# O problema central abordado neste trabalho é o desperdício de energia elétrica em ambientes industriais e centros de distribuição. Muitas organizações operam com picos de carga ineficientes, falhas não detectadas em equipamentos e ausência de monitoramento preditivo, o que gera custos elevados e impactos ambientais significativos. No Brasil, o setor industrial representa parcela expressiva do consumo energético nacional, e a ausência de mecanismos inteligentes de monitoramento dificulta ações preventivas e estratégias sustentáveis.
#
# Diante desse cenário, propõe-se o desenvolvimento de uma solução baseada em modelagem preditiva capaz de identificar padrões de consumo energético e antecipar comportamentos anômalos, contribuindo para a redução de desperdícios e aumento da eficiência operacional.

# %% [markdown]
# ## **2. Referêncial Teórico**
#
# A análise de séries temporais tem sido amplamente utilizada em problemas
# relacionados à previsão de demanda energética, constituindo uma ferramenta
# essencial para o planejamento e a otimização de recursos. Diversos estudos
# demonstram a eficácia tanto de modelos estatísticos quanto de técnicas de
# aprendizado de máquina na modelagem de dados temporais.
#
# Entre as abordagens estatísticas clássicas, destacam-se os modelos ARIMA
# (AutoRegressive Integrated Moving Average), amplamente empregados para
# capturar padrões de dependência temporal em séries estacionárias. Esses modelos
# apresentam como principais vantagens a interpretabilidade e a robustez em
# cenários com dados estruturados, embora possam apresentar limitações na
# modelagem de padrões não lineares (HYNDMAN; ATHANASOPOULOS, 2021).
#
# Para séries que apresentam sazonalidade, como é o caso do consumo
# energético, os modelos SARIMA (Seasonal ARIMA) são frequentemente utilizados,
# permitindo incorporar padrões periódicos na modelagem. No entanto, esses
# modelos exigem maior cuidado na definição de parâmetros e pressupõem certa
# regularidade nos padrões sazonais. Além dos métodos estatísticos, técnicas de
# aprendizado de máquina, como redes neurais e modelos baseados em árvores, têm
# sido aplicadas na previsão de consumo energético. Essas abordagens apresentam
# bom desempenho na captura de relações não lineares e interações complexas entre
# variáveis. Por outro lado, podem demandar maior volume de dados e apresentam
# menor interpretabilidade em comparação aos modelos tradicionais.
#
# De modo geral, a escolha da técnica mais adequada depende das
# características da série temporal analisada, como a presença de tendência,
# sazonalidade e nível de ruído. No contexto deste trabalho, a identificação dessas
# componentes por meio da análise exploratória fundamenta a escolha de modelos
# que considerem dependência temporal e padrões sazonais, como os modelos
# ARIMA e SARIMA.
#
#
#
# 4.1 Trabalhos Correlatos: A compreensão de como a literatura tem resolvido
# problemas semelhantes é essencial para a elaboração de modelos preditivos
# robustos, especialmente quando introduzimos dados exógenos de variáveis
# climáticas aos modelos estatísticos e computacionais. Segundo Passos e Müller
# (2025), o consumo energético destaca-se por sua alta variabilidade e sensibilidade a
# fatores externos, como atributos meteorológicos. O problema central investigado
# pelos autores foi a necessidade de maximizar a acurácia das previsões em relação
# aos métodos estatísticos tradicionais, como o ARIMA Para solucionar essa questão,
# propuseram o uso de Redes Neurais Artificiais densas (Perceptron de Múltiplas
# Camadas - MLP) alimentadas com dados temporais atrelados à temperatura,
# umidade, velocidade do vento e fluxos de radiação solar. Como resultado, o modelo
# estruturado com função de ativação ReLU e otimizador Adam alcançou um Erro
# Percentual Absoluto Médio (MAPE) de apenas 10,86%, superando significativamente
# o modelo estatístico tradicional ARIMA, que obteve uma taxa de erro maior, de
# 18,39%. Já no estudo de Oliveira Junior (2021), o problema focado foi a demanda
# por predições confiáveis sobre os níveis de consumo de energia para auxiliar no
# desenvolvimento de estratégias mais eficientes, combatendo desperdícios e
# impactos ambientais. A metodologia adotada baseou-se na implementação e
# calibração de redes neurais profundas focadas em séries temporais, testando
# arquiteturas como Long Short-Term Memory (LSTM) e Redes Neurais
# Convolucionais (CNN) no framework Python. O trabalho obteve resultados
# altamente satisfatórios, sendo que o melhor desempenho foi do modelo híbrido
# CNN+LSTM utilizando a função de perda Huber, alcançando um erro RMSE (Root
# Mean Squared Error) de 0,283 na fase de validação. Essa abordagem evidenciou ser
# uma solução robusta e com alta capacidade de generalização para cenários de
# previsão de consumo.

# %% [markdown]
# **3. Diagrama de Solução**
#
#
# O diagrama apresentado ilustra o fluxo completo do processo analítico, desde a coleta dos dados até a geração de insights, evidenciando as etapas de tratamento, análise e modelagem preditiva.
#
# ![Captura de Tela 2026-04-26 às 15.39.21.png](data:image/png;base64,...)

# %% [markdown]
# # **4. EDA e Pré-processamento dos dados**
# 4.1. DESCRIÇÃO DA BASE DE DADOS
# O conjunto de dados a ser utilizado será composto por séries temporais relacionadas ao consumo de energia elétrica no Brasil, obtidas a partir de fontes oficiais e confiáveis. Entre as principais fontes consideradas estão o Operador Nacional do Sistema Elétrico (ONS) e a Câmara de Comercialização de Energia Elétrica (CCEE), que disponibilizam bases públicas com informações detalhadas sobre carga energética.
# Os dados incluem registros temporais organizados por intervalos horários ou diários, contendo variáveis como data e hora, consumo energético em megawatts, classificação por subsistema ou setor econômico e possíveis variáveis auxiliares. Entre essas variáveis complementares, destacam-se dados meteorológicos, como temperatura média, que influenciam diretamente os padrões de consumo energético.
# A estrutura da base será organizada em formato tabular, adequada para processamento computacional e modelagem preditiva. Espera-se utilizar um período mínimo de cinco anos de dados históricos, permitindo capturar sazonalidades anuais, variações sazonais e efeitos macroeconômicos que impactam o comportamento energético.
# A escolha de bases públicas garante transparência, reprodutibilidade científica e facilidade de acesso, permitindo que outros pesquisadores ou instituições possam replicar ou expandir a solução proposta.
#
# 4.2. PREPARAÇÃO E ADEQUAÇÃO DA BASE DE DADOS
# A base de dados utilizada neste projeto é composta por registros de consumo de energia elétrica no Brasil ao longo do ano de 2025, com granularidade horária. Os dados foram obtidos de fontes confiáveis do setor elétrico e organizados em formato tabular.
# Inicialmente, realizou-se a importação da base utilizando a biblioteca Pandas, seguida da conversão da variável temporal para o formato datetime, ordenação cronológica dos registros e definição do índice temporal. Além disso, foi realizada a padronização dos nomes das colunas e a verificação da integridade dos dados.
# Não foram identificados valores ausentes, o que reforça a qualidade da base para análise. A série foi então filtrada para o subsistema SIN (Sistema Interligado Nacional), permitindo uma análise agregada e mais representativa do consumo energético brasileiro.
# 4.3. ANÁLISE EXPLORATÓRIA DA SÉRIE TEMPORAL
#
#
# 4.3.1 Visualização da Série
# A análise inicial da série temporal evidencia um comportamento altamente variável ao longo do tempo, característico de dados de consumo energético em alta frequência. Observa-se a presença de oscilações recorrentes, indicando a existência de padrões sazonais.
# A fim de facilitar a interpretação, foi realizada a agregação da série em frequência diária, permitindo melhor visualização da tendência ao longo do período.
# A análise da série agregada revela uma variação ao longo do ano, com níveis mais elevados no início e no final do período e redução nos meses intermediários, sugerindo a presença de tendência associada a fatores sazonais de longo prazo.
# Adicionalmente, ao analisar um recorte semanal da série, identifica-se um padrão recorrente de variação ao longo dos dias, evidenciando forte sazonalidade diária, associada aos ciclos de consumo ao longo do dia.
#
# 4.3.2 Estatísticas Descritivas
# A análise estatística da série temporal de consumo energético indica que o consumo médio foi de aproximadamente 19.902 MW, com desvio padrão de 14.416 MW, evidenciando elevada variabilidade ao longo do período analisado.
# Observou-se que os valores mínimos e máximos foram de 6.858 MW e 55.584 MW, respectivamente, indicando ampla amplitude no consumo energético.
# O elevado desvio padrão em relação à média indica que a série apresenta alta volatilidade, característica típica de dados de consumo energético em alta frequência, influenciados por variações ao longo do dia e pela dinâmica da atividade econômica.
#
# 4.4. ANÁLISE DE AUTOCORRELAÇÃO (ACF e PACF)
# A autocorrelação é uma medida estatística que permite avaliar a relação entre valores passados e presentes de uma série temporal, sendo fundamental para identificar padrões de dependência temporal (HYNDMAN; ATHANASOPOULOS, 2021).
# A análise da função de autocorrelação (ACF) evidencia a existência de dependência temporal na série, com valores significativos nos primeiros lags. Esse comportamento indica que os valores atuais do consumo energético estão relacionados a observações anteriores.
# Observa-se ainda que, à medida que o número de defasagens aumenta, os coeficientes de autocorrelação tendem a se aproximar de zero, sugerindo redução da influência de valores mais distantes no tempo.
# Por sua vez, a função de autocorrelação parcial (PACF) apresenta poucos lags com relevância estatística, indicando que a estrutura da série pode ser explicada por um número limitado de termos autoregressivos.
# Em conjunto, esses resultados indicam que a série possui dependência temporal significativa e é adequada para modelagem por meio de técnicas estatísticas de séries temporais.
# 4.5. DECOMPOSIÇÃO DA SÉRIE TEMPORAL
# A decomposição da série temporal permite identificar seus principais componentes estruturais — tendência, sazonalidade e resíduo — sendo amplamente utilizada na análise de séries temporais (HYNDMAN; ATHANASOPOULOS, 2021).
# A componente de tendência evidencia variações ao longo do período analisado, com níveis mais elevados no início do ano, redução ao longo dos meses intermediários e posterior recuperação no final do período. Esse comportamento indica a influência de fatores sazonais de longo prazo no consumo energético.
# A componente sazonal apresenta um padrão altamente regular e repetitivo, evidenciando forte sazonalidade associada ao ciclo diário de consumo energético.
# Por fim, o componente residual não apresenta estrutura definida, caracterizando-se como ruído aleatório, indicando que as principais variações da série foram capturadas pelas componentes de tendência e sazonalidade.
# 4.6. IDENTIFICAÇÃO DAS COMPONENTES DA SÉRIE
# Com base nas análises realizadas, conclui-se que a série temporal apresenta:
# Tendência não linear ao longo do tempo
# Forte sazonalidade diária
# Alta variabilidade associada à granularidade horária
# Componente residual aleatória
# Dessa forma, a série não pode ser considerada estacionária, sendo necessária a utilização de técnicas apropriadas para sua modelagem.
# Esses resultados reforçam a adequação da série para aplicação de modelos preditivos, contribuindo diretamente para os objetivos propostos no projeto.

# %%
from google.colab import files
uploaded = files.upload()

# %%
import pandas as pd

df = pd.read_csv('CARGA_ENERGIA_2025.csv', sep=';')

# %%
df.columns

# %%
df['din_instante'] = pd.to_datetime(df['din_instante'])
df = df.sort_values('din_instante')
df.set_index('din_instante', inplace=True)

# selecionar variável principal
serie = df['val_cargaenergiamwmed']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))
plt.plot(serie)
plt.title('Consumo de Energia ao Longo do Tempo')
plt.xlabel('Tempo')
plt.ylabel('Carga (MW)')
plt.show()

# %%
serie_diaria = serie.resample('D').mean()

plt.figure(figsize=(12,5))
plt.plot(serie_diaria)
plt.title('Consumo Médio Diário de Energia')
plt.xlabel('Tempo')
plt.ylabel('Carga (MW)')
plt.show()

# %%
serie_semana = serie['2025-01-01':'2025-01-07']

plt.figure(figsize=(12,5))
plt.plot(serie_semana)
plt.title('Consumo de Energia - Uma Semana')
plt.show()

# %% [markdown]
# A análise exploratória da série temporal de consumo energético revelou padrões relevantes ao longo do período analisado. Ao considerar a média diária, observa-se uma variação ao longo do ano, com níveis mais elevados no início e no final do período e redução no meio do ano, indicando a presença de tendência associada a fatores sazonais de longo prazo.
#
# Adicionalmente, ao analisar um recorte semanal da série, identifica-se um padrão recorrente de variação ao longo dos dias, evidenciando forte sazonalidade diária. Esse comportamento é característico do consumo energético, que varia de acordo com a atividade econômica e os ciclos de uso ao longo do dia.
#
#
# A presença de padrões cíclicos em diferentes escalas temporais indica que a série possui múltiplos níveis de sazonalidade, incluindo componentes diárias e possivelmente semanais, além de variações ao longo do ano. Dessa forma, a série apresenta comportamento não estacionário, exigindo técnicas apropriadas de modelagem para capturar tais características.

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plot_acf(serie, lags=50)
plt.show()

plot_pacf(serie, lags=50)
plt.show()

# %% [markdown]
# **ANÁLISE DE AUTOCORRELAÇÃO**
#
# A análise da função de autocorrelação (ACF) evidencia a existência de dependência temporal na série, com valores significativos nos primeiros lags. Esse comportamento indica que os valores atuais do consumo energético estão relacionados a observações anteriores, característica típica de séries temporais reais.
#
# Observa-se ainda que, à medida que o número de defasagens aumenta, os coeficientes de autocorrelação tendem a se aproximar de zero, sugerindo redução da influência de valores mais distantes no tempo.
#
# ANÁLISE PACF
#
# A função de autocorrelação parcial (PACF) apresenta poucos lags com relevância estatística, indicando que a estrutura da série pode ser explicada por um número limitado de termos autoregressivos. Esse resultado sugere que modelos relativamente simples podem ser suficientes para capturar o comportamento da série.
#
# Em conjunto, os resultados da ACF e PACF indicam que a série possui dependência temporal significativa, mas não apresenta comportamento puramente aleatório. Dessa forma, a série é adequada para modelagem utilizando técnicas estatísticas de séries temporais, como modelos ARIMA e suas variações.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decomposicao = seasonal_decompose(serie, model='additive', period=24)

decomposicao.plot()
plt.show()

# %% [markdown]
# A decomposição da série temporal permitiu identificar claramente três componentes principais: tendência, sazonalidade e resíduo
#
# A componente de tendência evidencia variações ao longo do período analisado, com níveis mais elevados no início do ano, redução ao longo dos meses intermediários e posterior recuperação no final do período. Esse comportamento indica a influência de fatores sazonais de longo prazo no consumo energético.
#
# A componente sazonal apresenta um padrão altamente regular e repetitivo, evidenciando forte sazonalidade associada ao ciclo diário de consumo. Esse resultado está alinhado com o comportamento esperado do consumo energético, que varia conforme os horários do dia.
#
# Por fim, o componente residual não apresenta estrutura definida, caracterizando-se como ruído aleatório. Isso indica que as principais variações sistemáticas da série foram capturadas pelas componentes de tendência e sazonalidade.

# %% [markdown]
# Com base nas análises realizadas — incluindo visualização gráfica, autocorrelação e decomposição — conclui-se que a série temporal apresenta tendência não linear, forte sazonalidade diária e componente residual aleatória, caracterizando-se como uma série não estacionária e adequada para modelagem preditiva.

# %%
serie.describe()

# %%
serie_diaria.describe()

# %% [markdown]
# **5. Modelagem Preditiva**

# %%
# ======================================
# MODELO BASE - ARIMA
# ======================================

from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
import matplotlib.pyplot as plt

# usar série diária
serie = serie_diaria

# divisão treino/teste (80% treino)
train_size = int(len(serie) * 0.8)
train, test = serie[:train_size], serie[train_size:]

# treinar modelo ARIMA
modelo = ARIMA(train, order=(2,1,2))
modelo_fit = modelo.fit()

# previsão
forecast = modelo_fit.forecast(steps=len(test))

# métricas
mae = mean_absolute_error(test, forecast)
mse = mean_squared_error(test, forecast)
rmse = np.sqrt(mse)

print(f"MAE: {mae}")
print(f"RMSE: {rmse}")

# gráfico
plt.figure(figsize=(12,5))
plt.plot(train, label='Treino')
plt.plot(test, label='Real')
plt.plot(test.index, forecast, label='Previsto')
plt.legend()
plt.title('Modelo ARIMA - Previsão de Consumo de Energia')
plt.xlabel('Tempo')
plt.ylabel('Carga (MW)')
plt.show()

# %% [markdown]
# Considerando a forte sazonalidade identificada na análise exploratória da série temporal, foi implementado um modelo SARIMA (Seasonal ARIMA), capaz de incorporar componentes sazonais na modelagem.
#
# O objetivo desta etapa é avaliar se a inclusão da sazonalidade melhora o desempenho preditivo em relação ao modelo ARIMA tradicional.

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
import matplotlib.pyplot as plt

# criar série diária
serie_diaria = df['val_cargaenergiamwmed'].resample('D').mean()

# visualizar
serie_diaria.head()
# usar série diária
serie = serie_diaria

# treino/teste
train_size = int(len(serie) * 0.8)
train, test = serie[:train_size], serie[train_size:]

# modelo SARIMA
modelo_sarima = SARIMAX(
    train,
    order=(2,1,2),
    seasonal_order=(1,1,1,7)
)

modelo_sarima_fit = modelo_sarima.fit()

# previsão
forecast_sarima = modelo_sarima_fit.forecast(steps=len(test))

# métricas
mae_sarima = mean_absolute_error(test, forecast_sarima)
rmse_sarima = np.sqrt(mean_squared_error(test, forecast_sarima))

print(f"MAE SARIMA: {mae_sarima}")
print(f"RMSE SARIMA: {rmse_sarima}")

# gráfico
plt.figure(figsize=(12,5))
plt.plot(test, label='Real')
plt.plot(test.index, forecast_sarima, label='SARIMA')
plt.legend()
plt.title('SARIMA - Previsão de Consumo Energético')
plt.show()

# %% [markdown]
# **Tabela Comparativa dos Modelos**
# 1.   Item da lista
# 2.   Item da lista
#
#
#
# A tabela abaixo apresenta os resultados obtidos pelos modelos ARIMA e SARIMA utilizando as métricas MAE e RMSE.

# %%
import pandas as pd

# criar tabela
comparacao = pd.DataFrame({
    'Modelo': ['ARIMA', 'SARIMA'],
    'MAE': [mae, mae_sarima],
    'RMSE': [rmse, rmse_sarima]
})

comparacao_rounded = comparacao.round(2)
display(comparacao_rounded)

# %% [markdown]
# **Comparação dos Modelos**
#
# A comparação entre os modelos ARIMA e SARIMA demonstrou que, neste conjunto de dados, o modelo ARIMA apresentou desempenho superior em relação ao SARIMA.
#
# Embora a série temporal apresente sazonalidade, o modelo SARIMA obteve erros significativamente maiores, indicando dificuldade em capturar adequadamente os padrões presentes na série.
#
# Esse resultado sugere que a sazonalidade observada pode possuir comportamento mais complexo ou irregular, dificultando o ajuste do modelo sazonal utilizado.
#
# Dessa forma, o modelo ARIMA mostrou-se mais adequado para o problema analisado, apresentando menor erro médio e melhor capacidade preditiva no contexto deste projeto.

# %% [markdown]
# Os resultados obtidos demonstram que modelos mais complexos nem sempre apresentam melhor desempenho preditivo, reforçando a importância da avaliação comparativa entre diferentes abordagens de modelagem.

# %% [markdown]
# **Análise por Subsistema**

# %%
import matplotlib.pyplot as plt

# Agrupar por subsistema
subsistemas = df['nom_subsistema'].unique()

plt.figure(figsize=(12,6))

for sub in subsistemas:
    serie_sub = df[df['nom_subsistema'] == sub]['val_cargaenergiamwmed']
    serie_sub = serie_sub.resample('D').mean()
    plt.plot(serie_sub, label=sub)

plt.legend()
plt.title('Consumo Médio Diário por Subsistema')
plt.show()

# %% [markdown]
# **6. ANÁLISE POR SUBSISTEMA**
#
#
# A análise segmentada por subsistema evidencia diferenças significativas no comportamento do consumo energético entre as regiões do Brasil. Observa-se que o subsistema Sudeste/Centro-Oeste apresenta os maiores níveis de consumo ao longo de todo o período analisado, refletindo sua elevada concentração populacional e atividade econômica.
#
# O subsistema Sul apresenta comportamento semelhante, porém em menor escala, enquanto o Nordeste apresenta níveis intermediários e maior estabilidade ao longo do tempo. Já o Norte apresenta os menores níveis de consumo, com menor variação relativa.
#
# Além disso, todos os subsistemas apresentam padrões recorrentes ao longo do tempo, evidenciando a presença de sazonalidade, possivelmente associada aos ciclos diários de consumo energético. Também é possível observar variações ao longo do ano, indicando a presença de tendência e influência de fatores sazonais de maior escala.
#
# Essa análise reforça a importância de considerar características regionais na modelagem da série temporal, uma vez que o comportamento do consumo energético varia significativamente entre os subsistemas.

# %% [markdown]
# **7. CONCLUSÃO**
#
# Este projeto teve como objetivo analisar padrões de consumo energético no Brasil e avaliar a aplicação de técnicas preditivas para apoio à redução de desperdícios energéticos.
#
# A análise exploratória permitiu identificar forte sazonalidade, tendência temporal e dependência entre observações consecutivas, evidenciando a adequação da série para modelagem estatística.
#
# Os modelos ARIMA e SARIMA foram implementados e comparados utilizando métricas de erro. Os resultados demonstraram que, para o conjunto de dados analisado, o modelo ARIMA apresentou melhor desempenho preditivo, indicando que modelos mais complexos nem sempre produzem melhores resultados.
#
# Além disso, a análise por subsistema evidenciou diferenças relevantes entre as regiões do país, reforçando a importância de abordagens regionais no monitoramento energético.
#
# Dessa forma, conclui-se que técnicas de séries temporais podem contribuir significativamente para estratégias de monitoramento inteligente, previsão de demanda e redução de desperdícios energéticos em ambientes industriais e sistemas de distribuição.

# %% [markdown]
# **8. APRESENTAÇÃO**
#
# https://www.youtube.com/watch?v=jCawjIumK1M

# %% [markdown]
# **9. REFERÊNCIAS**
#
# BOX, G. E. P .; COX, D. R. An analysis of transformations. Journal of the Royal
# Statistical Society, Series B, Statistical Methodology, v. 26, n. 2, p. 211-252, 1964.
#
# BRASIL. Ministério de Minas e Energia. Plano Nacional de Energia 2050. Brasília:
# EPE, 2020.
#
# CÂMARA DE COMERCIALIZAÇÃO DE ENERGIA ELÉTRICA (CCEE). Dados de
# consumo de energia. Disponível em: https://www.ccee.org.br/. Acesso em: 28 fev.
# 2026.
#
# DOANE, D. P .; SEWARD, L. E. Estatística aplicada à administração e economia. São
# Paulo: Grupo A, 2014.
#
# DOS PASSOS, J. R. M.; MÜLLER, M. R. Previsão de consumo energético com redes
# neurais artificiais usando Python. Iguazu Science, São Miguel do Iguaçu, v. 3, n. 7, p.
# 166-174, jun. 2025.
#
# GUERRERO, V. M. Time-series analysis supported by power transformations. Journal
# of Forecasting, v. 12, n. 1, p. 37-48, 1993.
# HYNDMAN, R. J.; ATHANASOPOULOS, G. Forecasting: principles and practice. 3. ed.
# Melbourne: OTexts, 2021. Disponível em: https://otexts.com/fpp3/. Acesso em: 28
# fev. 2026.
#
# IBM. What are ARIMA models? Disponível em:
# https://www.ibm.com/topics/arima-model. Acesso em 15 de setembro de 2024.
#
#
# IBM. What is a recurrent neural network (RNN)? Disponível em:
# https://www.ibm.com/topics/recurrent-neural-networks. Acesso em 15 de setembro
# de 2024.
#
# OLIVEIRA, A.; SILVEIRA, G. B.; BRAGA, J. M. Diversidade sazonal do consumo de
# energia elétrica no Brasil. Pesquisa de Planejamento Econômico. Rio de Janeiro:
# IPEA, 2000.
#
# OLIVEIRA JUNIOR, A. G. Calibração de modelos de rede neural para predição de
# consumo de energia. 2021. 68 f. Trabalho de Conclusão de Curso (Bacharelado em
# Ciência da Computação) – Instituto de Ciência e Tecnologia, Universidade Federal
# de São Paulo, São José dos Campos, 2021.
#
# ONU. World Population Prospects 2024. Disponível em: https://population.un.org/.
# Acesso em 22 de agosto de 2024.
#
# OPERADOR NACIONAL DO SISTEMA ELÉTRICO (ONS). Dados de carga por
# subsistema. Disponível em: https://dados.ons.org.br/. Acesso em: 28 fev. 2026.
#
# PALIT, A. K.; POPOVIC, D. Computational Intelligence in Time Series Forecasting. 1.
# ed. New York: Springer, 2005.
# SILVA, L. A.; PERES, S. M.; BOSCARIOLI, C. Intrdução à mineração de dados com
# aplicações em R. 1. ed. São Paulo: L TC, 2016.
